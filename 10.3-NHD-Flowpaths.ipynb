# %%
import dbfread as dbf
import pandas as pd
nhd_file = 'H:/My Drive/HAND/NHDPlusAttributes/PlusFlowlineVAA.dbf'
nhd = pd.DataFrame(iter(dbf.read(nhd_file)))
nhd
# Out:
#              ComID       Fdate  StreamLeve  StreamOrde  StreamCalc  \
# 0       22296626.0  2012-07-03         5.0         1.0         1.0
# 1       22297696.0  2012-07-03         5.0         1.0         1.0
# 2       22296564.0  2012-07-03         5.0         1.0         1.0
# 3       22296942.0  2012-07-03         5.0         2.0         2.0
# 4       22297542.0  2012-07-03         5.0         2.0         2.0
# ...            ...         ...         ...         ...         ...
# 129665   8412501.0  2012-07-03         2.0         1.0         1.0
# 129666   8412773.0  2012-07-03         1.0         1.0         1.0
# 129667   8410327.0  2012-07-03         2.0         1.0         1.0
# 129668   8410329.0  2012-07-03         1.0         1.0         1.0
# 129669   8412427.0  2012-07-03         1.0         1.0         1.0
#
#            FromNode       ToNode     Hydroseq   LevelPathI  Pathlength  ...  \
# 0       200085002.0  200085374.0  200071187.0  200046454.0     424.832  ...
# 1       200127446.0  200085002.0  200093409.0  200046454.0     426.265  ...
# 2       200127319.0  200085400.0  200093536.0  200042360.0     414.105  ...
# 3       200085074.0  200085359.0  200051831.0  200042360.0     412.687  ...
# 4       200085365.0  200085074.0  200059459.0  200042360.0     413.898  ...
# ...             ...          ...          ...          ...         ...  ...
# 129665  200046008.0  200046009.0  200004111.0  200004111.0       0.864  ...
# 129666  200046015.0  200046009.0  200004117.0  200004109.0       0.864  ...
# 129667  200111236.0  200045726.0  200004202.0  200004202.0       1.243  ...
# 129668  200111237.0  200045987.0  200004181.0  200004181.0       0.000  ...
# 129669  200111287.0  200046116.0  200004174.0  200004174.0       0.000  ...
#
#         DivEffect  VPUIn  VPUOut  AreaSqKM  TotDASqKM  DivDASqKM  Tidal  \
# 0             0.0    0.0     0.0    2.3652     4.5783     4.5783    0.0
# 1             0.0    0.0     0.0    2.2131     2.2131     2.2131    0.0
# 2             0.0    0.0     0.0    3.4092     3.4092     3.4092    0.0
# 3             0.0    0.0     0.0    2.6397     8.8965     8.8965    0.0
# 4             0.0    0.0     0.0    0.0000     6.2568     6.2568    0.0
# ...           ...    ...     ...       ...        ...        ...    ...
# 129665        0.0    0.0     0.0    0.0117     0.6183     0.6183    1.0
# 129666        0.0    0.0     0.0    0.2844     1.2744     1.2744    1.0
# 129667        0.0    0.0     0.0    0.0972     0.0972     0.0972    1.0
# 129668        0.0    0.0     0.0    0.0234     0.0234     0.0234    1.0
# 129669        0.0    0.0     0.0    0.0000     0.0000     0.0000    0.0
#
#               TOTMA  WBAreaType   PathTimeMA
# 0          0.067156               389.898097
# 1         50.149479    LakePond   389.965253
# 2          0.138575               330.033911
# 3          0.048928               329.635311
# 4          0.067569    LakePond   329.684239
# ...             ...         ...          ...
# 129665 -9999.000000             -9999.000000
# 129666 -9999.000000             -9999.000000
# 129667 -9999.000000             -9999.000000
# 129668 -9999.000000             -9999.000000
# 129669     0.008742                 0.000000
#
# [129670 rows x 40 columns]

# %%
# data = pd.read_csv('./HWM_Optimization/Iter6/HWM_Combined_Opt.csv')
fpath = 'H:/My Drive/020301/hydrogeo-fulltable-020301.csv'
data = pd.read_csv(fpath)
data.describe()
# Out:
#             CatchId          Stage  Number of Cells  SurfaceArea (m2)  \
# count  6.690630e+05  669063.000000     6.690630e+05      6.690630e+05
# mean   2.270895e+07      12.496800     9.070489e+03      7.290656e+05
# std    1.175866e+08       7.302494     2.107750e+04      1.696988e+06
# min    2.583257e+06       0.000000     0.000000e+00      0.000000e+00
# 25%    6.228268e+06       6.096000     7.600000e+02      6.096010e+04
# 50%    6.249814e+06      12.496800     2.741000e+03      2.195171e+05
# 75%    7.733967e+06      18.897600     9.023000e+03      7.238119e+05
# max    9.320403e+08      24.993600     1.068238e+06      8.587612e+07
#
#        BedArea (m2)   Volume (m3)          SLOPE       LENGTHKM  \
# count  6.690630e+05  6.690630e+05  669063.000000  669063.000000
# mean   8.290269e+05  6.967548e+06     -30.995744       1.305576
# std    1.917159e+06  1.931590e+07     555.923469       1.502085
# min    0.000000e+00 -1.178300e-02   -9998.000000       0.001000
# 25%    6.213195e+04  2.752265e+05       0.000010       0.283000
# 50%    2.271624e+05  1.470223e+06       0.003633       0.791000
# 75%    7.628493e+05  5.863380e+06       0.014266       1.848000
# max    8.596123e+07  1.074208e+09       0.350000      24.645000
#
#             AREASQKM     Roughness   TopWidth (m)  WettedPerimeter (m)  \
# count  669063.000000  6.690630e+05  669063.000000        669063.000000
# mean        1.818520  5.000000e-02     515.074518           614.680556
# std         3.517645  4.434789e-13    1012.183864          1716.945583
# min         0.000900  5.000000e-02       0.000000             0.000000
# 25%         0.179100  5.000000e-02     156.838910           161.158337
# 50%         0.748800  5.000000e-02     313.443474           322.064051
# 75%         2.194200  5.000000e-02     584.592569           609.759746
# max       110.801700  5.000000e-02   53845.317328         54628.332128
#
#        WetArea (m2)  HydraulicRadius (m)  Discharge (m3s-1)
# count  6.690630e+05         6.690630e+05       6.668800e+05
# mean   4.960474e+03         7.928803e+00       2.663557e+04
# std    1.145900e+04         5.406724e+00       7.539112e+04
# min   -1.037692e-05        -2.553260e-07       0.000000e+00
# 25%    6.823480e+02         3.367414e+00       5.450450e+02
# 50%    2.445328e+03         7.355600e+00       5.407264e+03
# 75%    5.801528e+03         1.172857e+01       3.073391e+04
# max    1.007205e+06         2.499360e+01       7.255098e+06

# %%
a = data[data.CatchId == 6251128] # poorly calibrated
b = data[data.CatchId == 6251234] # poorly calibrated
c = data[data.CatchId == 6251308] # poorly calibrated
d = data[data.CatchId == 6249784] # poorly calibrated
e = data[data.CatchId == 6251122] # poorly calibrated

f = data[data.CatchId == 6251098] # well calibrated
g = data[data.CatchId == 932030163] # well calibrated
h = data[data.CatchId == 6251026]

for catch in [a,b,c,d,e,f,g,h]:
    print(catch.SLOPE.unique())
# Out:
# [1.e-05]
# [1.e-05]
# [1.e-05]
# [1.e-05]
# [1.e-05]
# [0.00065582]
# [0.00185479]
# [0.00734138]

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rc('axes', labelsize=20) 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

# fig, ax = plt.subplots()
ax.scatter(x=a['Discharge (m3s-1)'], y=a['Stage'],label='',c='red')
ax.scatter(x=b['Discharge (m3s-1)'], y=b['Stage'],label='',c='orange')
ax.scatter(x=c['Discharge (m3s-1)'], y=c['Stage'],label='',c='yellow')
ax.scatter(x=d['Discharge (m3s-1)'], y=d['Stage'],label='',c='green')
ax.scatter(x=e['Discharge (m3s-1)'], y=e['Stage'],label='',c='blue')
ax.scatter(x=f['Discharge (m3s-1)'], y=f['Stage'],label='Good',c='purple')
ax.scatter(x=g['Discharge (m3s-1)'], y=g['Stage'],label='Good',c='gray')
ax.scatter(x=h['Discharge (m3s-1)'], y=h['Stage'],label='Good',c='black')

ax.legend()
# lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
# now plot both limits against eachother
ax.plot()
# ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
# ax.set_aspect('equal')
ax.set_xlim([-100,3000])
# ax.set_ylim(lims)
plt.xlabel("Discharge (m3s-1)")
plt.ylabel("Stage")
plt.grid(color = 'gray', linestyle='--',linewidth = 0.5)
plt.savefig('StreamDepth.png')

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rc('axes', labelsize=20) 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

# fig, ax = plt.subplots()
ax.scatter(x=a['WetArea (m2)'], y=a['Stage'],label='',c='red')
ax.scatter(x=b['WetArea (m2)'], y=b['Stage'],label='',c='orange')
ax.scatter(x=c['WetArea (m2)'], y=c['Stage'],label='',c='yellow')
ax.scatter(x=d['WetArea (m2)'], y=d['Stage'],label='',c='green')
ax.scatter(x=e['WetArea (m2)'], y=e['Stage'],label='',c='blue')
ax.scatter(x=f['WetArea (m2)'], y=f['Stage'],label='Good',c='purple')
ax.scatter(x=g['WetArea (m2)'], y=g['Stage'],label='Good',c='gray')
ax.scatter(x=h['WetArea (m2)'], y=h['Stage'],label='Good',c='black')

ax.legend()
# lims = [np.min([ax.get_xlim(), ax.get_ylim()]), np.max([ax.get_xlim(), ax.get_ylim()])]
# now plot both limits against eachother
ax.plot()
# ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
# ax.set_aspect('equal')
ax.set_xlim([-100,3000])
# ax.set_ylim(lims)
plt.xlabel("WetArea (m2)")
plt.ylabel("Stage")
plt.grid(color = 'gray', linestyle='--',linewidth = 0.5)
plt.savefig('StreamDepth.png')

# %%
rmse = ((data['Stream_H_m'] - data['Predict_Stream_H_m']) ** 2).mean() ** .5
print("\nRMSE = " + str(round(rmse,6)))
# Out:
# RMSE = 1.251442

# %%
correlation_matrix = np.corrcoef(data['Stream_H_m'], data['Predict_Stream_H_m'])
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
r_squared
# Out:
# 0.47699154300948715

# %%
import scipy
# slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(data['Stream_H_m'], data['Predict_Stream_H_m'])
# print(slope, intercept, r_value, p_value, std_err)
scipy.stats.linregress(data['Stream_H_m'], data['Predict_Stream_H_m'])
# Out:
# LinregressResult(slope=0.8068667621323719, intercept=0.7223949776360823, rvalue=0.7629925914002844, pvalue=5.6510015059412145e-183, stderr=0.022131636155689326)

# %%
data
# Out:
#      Unnamed: 0  OBJECTID *  SITE_NUM HWM_ID   SITE_ID     NAME  \
# 0             0           2         1      2     ASSU1  ASSU1_2
# 1             1           3         1      3     ASSU1  ASSU1_3
# 2             2           4         1      4     ASSU1  ASSU1_4
# 3             3           5         2      1     ASSU2  ASSU2_1
# 4             4           6         2      2     ASSU2  ASSU2_2
# ..          ...         ...       ...    ...       ...      ...
# 951         951          27        60    NaN  Somerset      NaN
# 952         952          56       107    NaN  Somerset      NaN
# 953         953          63       115    NaN  Somerset      NaN
# 954         954          62       114    NaN  Somerset      NaN
# 955         955          31        68    NaN  Somerset      NaN
#
#             LAT_DD         LON_DD  HWM_ELEV_ft  HWM_ELEV_m  ...    HAND_m  \
# 0        40.211139     -74.762472      26.3375    8.027670  ...  6.840959
# 1        40.210889     -74.763111      24.3275    7.415022  ...  6.481321
# 2        40.210889     -74.763222      24.2275    7.384542  ...  6.481321
# 3        40.217500     -74.767917      19.9350    6.076188  ...  5.097004
# 4        40.217389     -74.768083      19.8250    6.042660  ...  5.565677
# ..             ...            ...          ...         ...  ...       ...
# 951  625181.134200  468199.584400      47.6254   14.516222  ...  6.369551
# 952  629101.816800  484529.513000      36.3069   11.066343  ...  5.057386
# 953  631875.527600  477348.825100      52.6148   16.036991  ...  9.578168
# 954  632110.714500  477320.712300      53.0096   16.157326  ...  9.169795
# 955  651649.361200  509814.901400      78.5875   23.953470  ...  9.876820
#
#      Inun_Depth_m  Stream_H_m    COMID  StreamOrde         fmax    time_file  \
# 0        0.681777    7.522736  4481733           6  5024.489888  20110829_07
# 1        1.422757    7.904078  4481733           6  5024.489888  20110829_07
# 2        1.706220    8.187541  4481733           6  5024.489888  20110829_07
# 3       -0.378092    4.718912  2590137           3   435.669990  20110828_08
# 4       -1.086848    4.478829  2590137           3   435.669990  20110828_08
# ..            ...         ...      ...         ...          ...          ...
# 951      0.590932    6.960483  9513382           5  1593.829964  20110828_18
# 952      2.159721    7.217107  9514000           6  2586.619942  20110828_20
# 953     -0.963599    8.614569  9513850           3   127.239997  20110828_06
# 954     -0.239994    8.929801  9513850           3   127.239997  20110828_06
# 955      0.045140    9.921960  9513118           2    58.989999  20110828_05
#
#     Predict_Stream_H_m  roughness      RMSE
# 0             7.851095   0.039937  0.273144
# 1             7.851095   0.039937  0.273144
# 2             7.851095   0.039937  0.273144
# 3             4.452237   0.029694  0.630860
# 4             4.452237   0.029694  0.630860
# ..                 ...        ...       ...
# 951           6.338650   0.006644  0.629992
# 952           6.886389   0.005000  1.443823
# 953           3.987255   0.300000  2.502124
# 954           3.987255   0.300000  2.502124
# 955           6.341750   0.300000  3.580210
#
# [956 rows x 21 columns]

# %%
catch = data.drop_duplicates(subset='COMID')
# catch = catch.drop(labels=['SITE_NUM', 'HWM_ID', 'SITE_ID', 'NAME', 'LAT_DD', 'LON_DD', 'HWM_ELEV_ft', \
#         'HWM_ELEV_m','DEM_m','HAND_m','Inun_Depth_m', 'time_file'], axis='columns')
catch
# Out:
#      Unnamed: 0  Unnamed: 0.1  OID_  OID1  SITE_NUM  HWM_ID   SITE_ID  \
# 0             0             0  1039   NaN       NaN     NaN  Somerset
# 1             1             1  1046   NaN       NaN     NaN  Somerset
# 2             2             2  1037   NaN       NaN     NaN  Somerset
# 3             3             3  1036   NaN       NaN     NaN  Somerset
# 6             6             6   969   NaN       NaN     NaN  Somerset
# ..          ...           ...   ...   ...       ...     ...       ...
# 967        1005          1005   924   NaN     152.0     1.0     WHIP5
# 975        1013          1013   932   NaN     153.0     1.0     WHIP6
# 982        1021          1021   940   NaN     154.0     2.0     WHIP7
# 989        1028          1028   947   NaN     155.0     3.0     WHIP8
# 995        1034          1034   953   NaN     156.0     1.0     WHIP9
#
#         NAME     LAT_DD     LON_DD  ...       dev  Cleaning_note         fmax  \
# 0          4  40.509285 -74.570339  ...       NaN            NaN    22.320000
# 1          5  40.469505 -74.544521  ...       NaN            NaN    80.229998
# 2          6  40.374587 -74.618079  ...       NaN            NaN   799.439982
# 3          7  40.399474 -74.627159  ...       NaN            NaN   789.229982
# 6         12  40.565279 -74.637317  ...       NaN            NaN  1582.159965
# ..       ...        ...        ...  ...       ...            ...          ...
# 967  WHIP5_1  40.815861 -74.445556  ...  1.311436            NaN   124.039997
# 975  WHIP6_1  40.801222 -74.465972  ...  1.919210            NaN   128.389997
# 982  WHIP7_2  40.812944 -74.480833  ...  0.646009            NaN   119.439997
# 989  WHIP8_3  40.813028 -74.505528  ...  0.324511            NaN    83.739998
# 995  WHIP9_1  40.790861 -74.550694  ...  0.566721            NaN    47.009999
#
#        time_file  Predict_Stream_H_m  roughness          rmse      RMSE  \
# 0    20110828_05            1.337078   0.005000  1.265936e-01  0.126594
# 1    20110828_05            2.056241   0.005000  5.942049e-01  0.594205
# 2    20110828_11            3.944849   0.034375  3.060844e-07       0.0
# 3    20110828_13            4.466071   0.008638  1.285609e-01  0.128561
# 6    20110828_17            5.590755   0.096550  5.288467e-01  0.528847
# ..           ...                 ...        ...           ...       ...
# 967  20110828_14            2.107789   0.009362  9.469104e-01   0.94691
# 975  20110828_13            2.274434   0.022687  1.159648e+00  1.159648
# 982  20110828_13            2.144793   0.113028  6.982896e-01   0.69829
# 989  20110828_13            2.132867   0.074551  5.501594e-01  0.550159
# 995  20110828_12            2.007704   0.200000  5.255855e-01  0.525586
#
#      CatchId StreamOrde
# 0    9513572        2.0
# 1    9514722        2.0
# 2    9515554        4.0
# 3    9515544        4.0
# 6    9513352        5.0
# ..       ...        ...
# 967  6250088        3.0
# 975  6250748        3.0
# 982  6250092        3.0
# 989  6250744        2.0
# 995  6250138        2.0
#
# [194 rows x 28 columns]

# %%
# subset = data.loc[data.StreamOrde == 1]
# subset.COMID.unique()

# %%
print("Order  Avg_Fmax  Avg_H  Avg_rough  Avg_RMSE  COMIDs  Pt_Count")
for order in np.sort(catch.StreamOrde.unique()):
    subset = catch.loc[catch.StreamOrde == order]
    print(f'{order: 3}  {round(subset.fmax.mean(),1):9}  {round(subset.Predict_Stream_H_m.mean(),1):5}\
    {round(subset.roughness.mean(),3):6}  {round(subset.RMSE.mean(),2):7} {len(subset.COMID.unique()):7} \
    {round(len(subset),1):7}')
# Out:
# Order  Avg_Fmax  Avg_H  Avg_rough  Avg_RMSE  COMIDs  Pt_Count
#  1.0        7.6    1.0     0.195     2.11       8           8
#  2.0       55.3    1.9     0.086     0.48      38          38
#  3.0      197.2    2.7     0.058      0.4      56          56
#  4.0      532.4    2.9     0.031     0.54      53          53
#  5.0     1143.0    4.7     0.049     0.57      22          22
#  6.0     2666.1    5.5     0.012      1.4      17          17

# %%
print("Order  Med_Fmax  Med_H  Med_rough  Med_RMSE  COMIDs  Pt_Count")
for order in np.sort(catch.StreamOrde.unique()):
    subset = catch.loc[catch.StreamOrde == order]
    print(f'{order: 3}  {round(subset.fmax.median(),1):9}  {round(subset.Predict_Stream_H_m.median(),1):5}\
    {round(subset.roughness.median(),3):6}  {round(subset.RMSE.median(),2):7} {len(subset.COMID.unique()):7} \
    {round(len(subset),1):7}')
# Out:
# Order  Med_Fmax  Med_H  Med_rough  Med_RMSE  COMIDs  Pt_Count
#  1.0        3.1    1.0       0.2     1.37       8           8
#  2.0       47.2    1.9      0.06     0.34      38          38
#  3.0      160.0    2.6      0.04     0.25      56          56
#  4.0      550.1    2.8      0.02     0.23      53          53
#  5.0      989.3    5.2     0.009      0.1      22          22
#  6.0     2485.8    6.2     0.005     0.62      17          17

# %%
catch2 = catch[catch.roughness < 0.299]
catch2 = catch2[catch2.roughness > 0.0051]

# %%
print("Order  Avg_Fmax  Avg_H  Avg_rough  Avg_RMSE  COMIDs  Pt_Count")
for order in np.sort(catch2.StreamOrde.unique()):
    subset = catch2.loc[catch2.StreamOrde == order]
    print(f'{order: 3}  {round(subset.fmax.mean(),1):9}  {round(subset.Predict_Stream_H_m.mean(),1):5}\
    {round(subset.roughness.mean(),3):6}  {round(subset.RMSE.mean(),2):7}   {len(subset.COMID.unique()):7} \
    {round(len(subset),1):4}')
# Out:
# Order  Avg_Fmax  Avg_H  Avg_rough  Avg_RMSE  COMIDs  Pt_Count
#   1       11.8    5.8     0.071      0.0         1        1
#   2       61.4    2.3     0.077     0.21        25       25
#   3      201.9    3.1      0.07      0.2        49       49
#   4      537.0    3.3     0.041     0.24        41       41
#   5     1138.4    5.2     0.046     0.16        16       16
#   6     2854.4    5.2     0.023     0.14         8        8

# %%
print("Order  Med_Fmax  Med_H  Med_rough  Med_RMSE  COMIDs  Pt_Count")
for order in np.sort(catch2.StreamOrde.unique()):
    subset = catch2.loc[catch2.StreamOrde == order]
    print(f'{order: 3}  {round(subset.fmax.median(),1):9}  {round(subset.Predict_Stream_H_m.median(),1):5}\
    {round(subset.roughness.median(),3):6}  {round(subset.RMSE.median(),2):7} {len(subset.COMID.unique()):7} \
    {round(len(subset),1):7}')
# Out:
# Order  Med_Fmax  Med_H  Med_rough  Med_RMSE  COMIDs  Pt_Count
#   1       11.8    5.8     0.071      0.0       1           1
#   2       53.1    2.2     0.061     0.16      25          25
#   3      156.8    2.8     0.055     0.15      49          49
#   4      550.1    3.2      0.03     0.18      41          41
#   5      989.3    5.4     0.014     0.09      16          16
#   6     2541.5    5.2     0.021     0.06       8           8

# %%
catch.describe()

# %%
catch_data1 = pd.read_csv('CatchPointsWithData_DEM.csv')
catch_data1

# %%
catch_data2 = pd.read_csv('CatchPointsWithRunoffC.csv')
catch_data2

# %%
catch2 = catch.merge(catch_data1, on='COMID')
catch2 = catch2.merge(catch_data2, on='COMID')
catch2

# %%
catch3 = catch2.drop_duplicates(subset='COMID')
catch3

# %%
# catch3.to_csv('./Iter6/HWM_Combined_Opt_DEM.csv')

# %%
data_x = pd.read_csv('./Cleaned Hwm/hydrogeo-fulltable-020999.csv')
data_x

# %%
data_x = data_x.drop_duplicates(subset='CatchId')
data_x

# %%
catch4 = catch3.merge(data_x, left_on='COMID', right_on='CatchId')
catch4

# %%
# catch4.to_csv('./Iter6/HWM_Combined_Opt_DEM.csv')
